# %% [markdown]
# ## Import libraries

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from elasticsearch_dsl import Search
import pandas as pd
import json

# %% [markdown]
# ## Connect to elasticsearch

# %%
def connect_ES():
    return Elasticsearch(hosts='192.168.70.120', port=39200,timeout=60)

# %% [markdown]
# ## Get data

# %%
def scan_data(es,body):
    return helpers.scan(es,query=body)

# %%
def get_explanation_data_by_id():
    # query: The elasticsearch query.
    query = {
        "query": {
            "match": {
                "symbols.keyword": "BTC"
            }
        }
    }
    # Scan function to get all the data. 
    rel = scan(client=es,             
               query=query,                                     
               scroll='1m',
               index='tweets',
               raise_on_error=True,
               preserve_order=False,
               clear_scroll=True)
    # Keep response in a list.
    result = list(rel)
    temp = []
    # We need only '_source', which has all the fields required.
    # This elimantes the elasticsearch metdata like _id, _type, _index.
    for hit in result:
        temp.append(hit['_source'])
    # Create a dataframe.
    df = pd.DataFrame(temp)
    return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26792/999111020.py in <module>
#       1 es=connect_ES()
# ----> 2 scan_data(es,body)
#
# NameError: name 'body' is not defined

# %%
test_query = {
    "query": {
    "query_string": {
      "fields":"explanation"
    }
    }
}
es.search(index="body=)
# Out:
# <generator object scan at 0x00000186226474C8>

# %%
es = connect_ES()
index_list = [index for index in es.indices.get('*')]
ex_index_list = [i for i in index_list if 'ai-alert-int' in i]
ex_index_list
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using positional arguments for APIs is deprecated and will be disabled in 8.0.0. Instead use only keyword arguments for all APIs. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ...

# %%
internet_list = []
intranet_list = []
for i in ex_index_list:
    response = es.search(index=i)
    if i[9:17]=='internet':
        internet_list.append(response)
    elif i[9:17]=='intranet':
        intranet_list.append(response)
    else:
        print("error")

# %%
print(len(internet_list[0]))
internet_list
# Out:
# 4
# [{'took': 1,
#   'timed_out': False,
#   '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#   'hits': {'total': {'value': 8, 'relation': 'eq'},
#    'max_score': 1.0,
#    'hits': [{'_index': 'ai-alert-internet-2021-12',
#      '_type': '_doc',
#      '_id': 'LlLYTH4BW63vocbT1aak',
#      '_score': 1.0,
#      '_source': {'category': 'Internet',
#       'flow_id': 'B21120001',
#       'event_type': 'alert',
#       'in_iface': 'None',
#       'alert_id': 'T0971',
#       'alert_name': 'alert_name T0971',
#       'src_ip': '192.168.70.78',
#       'src_port': '8',
#       'dst_ip': '8.8.8.9',
#       'dst_port': '77',
#       'risk_level': 'Low',
#       'protocol': '17',
#       'start_time': '2021-12-31T04:46:46.250193+08:00',
#       'end_time': '2021-12-31T04:46:46.250193+08:00',
#       'timestamp': '2021-12-31T04:46:46.250193+08:00',
#       'ingest_timestamp': '2021-12-31T04:46:46.250193+08:00',
#       'module': 'byLongLife',
# ...

# %%
test_internet_list = [{'took': 1,
  'timed_out': False,
  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
  'hits': {'total': {'value': 8, 'relation': 'eq'},
   'max_score': 1.0,
   'hits': [{'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'LlLYTH4BW63vocbT1aak',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120001',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0971',
      'alert_name': 'alert_name T0971',
      'src_ip': '192.168.70.78',
      'src_port': '8',
      'dst_ip': '8.8.8.9',
      'dst_port': '77',
      'risk_level': 'Low',
      'protocol': '17',
      'start_time': '2021-12-31T04:46:46.250193+08:00',
      'end_time': '2021-12-31T04:46:46.250193+08:00',
      'timestamp': '2021-12-31T04:46:46.250193+08:00',
      'ingest_timestamp': '2021-12-31T04:46:46.250193+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'L1LYTH4BW63vocbT1qZO',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120002',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0947',
      'alert_name': 'alert_name T0947',
      'src_ip': '192.168.70.78',
      'src_port': '10',
      'dst_ip': '8.8.8.0',
      'dst_port': '65',
      'risk_level': 'Low',
      'protocol': '17',
      'start_time': '2021-12-31T22:13:13.330740+08:00',
      'end_time': '2021-12-31T22:13:13.330740+08:00',
      'timestamp': '2021-12-31T22:13:13.330740+08:00',
      'ingest_timestamp': '2021-12-31T22:13:13.330740+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'MFLYTH4BW63vocbT1qZa',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120003',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0932',
      'alert_name': 'alert_name T0932',
      'src_ip': '192.168.70.79',
      'src_port': '17',
      'dst_ip': '8.8.8.7',
      'dst_port': '90',
      'risk_level': 'High',
      'protocol': '6',
      'start_time': '2021-12-30T17:41:41.516453+08:00',
      'end_time': '2021-12-30T17:41:41.516453+08:00',
      'timestamp': '2021-12-30T17:41:41.516453+08:00',
      'ingest_timestamp': '2021-12-30T17:41:41.516453+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'MVLYTH4BW63vocbT1qZm',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120004',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0940',
      'alert_name': 'alert_name T0940',
      'src_ip': '192.168.70.70',
      'src_port': '2',
      'dst_ip': '8.8.8.6',
      'dst_port': '44',
      'risk_level': 'High',
      'protocol': '17',
      'start_time': '2021-12-30T00:38:38.990528+08:00',
      'end_time': '2021-12-30T00:38:38.990528+08:00',
      'timestamp': '2021-12-30T00:38:38.990528+08:00',
      'ingest_timestamp': '2021-12-30T00:38:38.990528+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'M1LYTH4BW63vocbT1qZ1',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120006',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0908',
      'alert_name': 'alert_name T0908',
      'src_ip': '192.168.70.74',
      'src_port': '4',
      'dst_ip': '8.8.8.8',
      'dst_port': '36',
      'risk_level': 'High',
      'protocol': '6',
      'start_time': '2021-12-30T08:13:13.626745+08:00',
      'end_time': '2021-12-30T08:13:13.626745+08:00',
      'timestamp': '2021-12-30T08:13:13.626745+08:00',
      'ingest_timestamp': '2021-12-30T08:13:13.626745+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'NFLYTH4BW63vocbT1qaR',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120007',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0905',
      'alert_name': 'alert_name T0905',
      'src_ip': '192.168.70.79',
      'src_port': '9',
      'dst_ip': '8.8.8.4',
      'dst_port': '26',
      'risk_level': 'Critical',
      'protocol': '17',
      'start_time': '2021-12-30T13:43:43.228390+08:00',
      'end_time': '2021-12-30T13:43:43.228390+08:00',
      'timestamp': '2021-12-30T13:43:43.228390+08:00',
      'ingest_timestamp': '2021-12-30T13:43:43.228390+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'NVLYTH4BW63vocbT1qau',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120008',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0984',
      'alert_name': 'alert_name T0984',
      'src_ip': '192.168.70.79',
      'src_port': '8',
      'dst_ip': '8.8.8.7',
      'dst_port': '100',
      'risk_level': 'High',
      'protocol': '17',
      'start_time': '2021-12-30T11:41:41.816942+08:00',
      'end_time': '2021-12-30T11:41:41.816942+08:00',
      'timestamp': '2021-12-30T11:41:41.816942+08:00',
      'ingest_timestamp': '2021-12-30T11:41:41.816942+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2021-12',
     '_type': '_doc',
     '_id': 'NlLYTH4BW63vocbT1qbD',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B21120009',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0964',
      'alert_name': 'alert_name T0964',
      'src_ip': '192.168.70.72',
      'src_port': '15',
      'dst_ip': '8.8.8.5',
      'dst_port': '88',
      'risk_level': 'High',
      'protocol': '17',
      'start_time': '2021-12-31T01:20:20.033001+08:00',
      'end_time': '2021-12-31T01:20:20.033001+08:00',
      'timestamp': '2021-12-31T01:20:20.033001+08:00',
      'ingest_timestamp': '2021-12-31T01:20:20.033001+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}}]}},
 {'took': 1,
  'timed_out': False,
  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
  'hits': {'total': {'value': 34, 'relation': 'eq'},
   'max_score': 1.0,
   'hits': [{'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'N1LZTH4BW63vocbTuKbG',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B2201000b',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0996',
      'alert_name': 'alert_name T0996',
      'src_ip': '192.168.70.77',
      'src_port': '8',
      'dst_ip': '8.8.8.4',
      'dst_port': '35',
      'risk_level': 'High',
      'protocol': '6',
      'start_time': '2022-01-09T13:14:14.978564+08:00',
      'end_time': '2022-01-09T13:14:14.978564+08:00',
      'timestamp': '2022-01-09T13:14:14.978564+08:00',
      'ingest_timestamp': '2022-01-09T13:14:14.978564+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'OFLZTH4BW63vocbTuaZn',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B2201000c',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0942',
      'alert_name': 'alert_name T0942',
      'src_ip': '192.168.70.77',
      'src_port': '10',
      'dst_ip': '8.8.8.6',
      'dst_port': '27',
      'risk_level': 'Medium',
      'protocol': '6',
      'start_time': '2022-01-04T14:13:13.423610+08:00',
      'end_time': '2022-01-04T14:13:13.423610+08:00',
      'timestamp': '2022-01-04T14:13:13.423610+08:00',
      'ingest_timestamp': '2022-01-04T14:13:13.423610+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'OVLZTH4BW63vocbTuaZ3',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B2201000d',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0963',
      'alert_name': 'alert_name T0963',
      'src_ip': '192.168.70.72',
      'src_port': '1',
      'dst_ip': '8.8.8.0',
      'dst_port': '38',
      'risk_level': 'Low',
      'protocol': '17',
      'start_time': '2022-01-04T17:23:23.653588+08:00',
      'end_time': '2022-01-04T17:23:23.653588+08:00',
      'timestamp': '2022-01-04T17:23:23.653588+08:00',
      'ingest_timestamp': '2022-01-04T17:23:23.653588+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'O1LZTH4BW63vocbTuaaG',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B2201000f',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0962',
      'alert_name': 'alert_name T0962',
      'src_ip': '192.168.70.78',
      'src_port': '17',
      'dst_ip': '8.8.8.0',
      'dst_port': '18',
      'risk_level': 'Medium',
      'protocol': '6',
      'start_time': '2022-01-05T11:29:29.201324+08:00',
      'end_time': '2022-01-05T11:29:29.201324+08:00',
      'timestamp': '2022-01-05T11:29:29.201324+08:00',
      'ingest_timestamp': '2022-01-05T11:29:29.201324+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'PFLZTH4BW63vocbTuaaU',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010010',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0982',
      'alert_name': 'alert_name T0982',
      'src_ip': '192.168.70.73',
      'src_port': '15',
      'dst_ip': '8.8.8.8',
      'dst_port': '93',
      'risk_level': 'Medium',
      'protocol': '17',
      'start_time': '2022-01-01T06:23:23.291639+08:00',
      'end_time': '2022-01-01T06:23:23.291639+08:00',
      'timestamp': '2022-01-01T06:23:23.291639+08:00',
      'ingest_timestamp': '2022-01-01T06:23:23.291639+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'PVLZTH4BW63vocbTuaaw',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010011',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0939',
      'alert_name': 'alert_name T0939',
      'src_ip': '192.168.70.73',
      'src_port': '17',
      'dst_ip': '8.8.8.6',
      'dst_port': '45',
      'risk_level': 'Low',
      'protocol': '17',
      'start_time': '2022-01-04T14:46:46.058232+08:00',
      'end_time': '2022-01-04T14:46:46.058232+08:00',
      'timestamp': '2022-01-04T14:46:46.058232+08:00',
      'ingest_timestamp': '2022-01-04T14:46:46.058232+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'PlLZTH4BW63vocbTuabP',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010012',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0958',
      'alert_name': 'alert_name T0958',
      'src_ip': '192.168.70.73',
      'src_port': '13',
      'dst_ip': '8.8.8.0',
      'dst_port': '34',
      'risk_level': 'Medium',
      'protocol': '17',
      'start_time': '2022-01-02T21:48:48.578806+08:00',
      'end_time': '2022-01-02T21:48:48.578806+08:00',
      'timestamp': '2022-01-02T21:48:48.578806+08:00',
      'ingest_timestamp': '2022-01-02T21:48:48.578806+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'P1LZTH4BW63vocbTuabj',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010013',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0954',
      'alert_name': 'alert_name T0954',
      'src_ip': '192.168.70.78',
      'src_port': '12',
      'dst_ip': '8.8.8.7',
      'dst_port': '44',
      'risk_level': 'Medium',
      'protocol': '6',
      'start_time': '2022-01-07T16:10:10.111069+08:00',
      'end_time': '2022-01-07T16:10:10.111069+08:00',
      'timestamp': '2022-01-07T16:10:10.111069+08:00',
      'ingest_timestamp': '2022-01-07T16:10:10.111069+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'QFLZTH4BW63vocbTuqYH',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010014',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0966',
      'alert_name': 'alert_name T0966',
      'src_ip': '192.168.70.78',
      'src_port': '8',
      'dst_ip': '8.8.8.5',
      'dst_port': '51',
      'risk_level': 'Medium',
      'protocol': '6',
      'start_time': '2022-01-07T17:14:14.288024+08:00',
      'end_time': '2022-01-07T17:14:14.288024+08:00',
      'timestamp': '2022-01-07T17:14:14.288024+08:00',
      'ingest_timestamp': '2022-01-07T17:14:14.288024+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}},
    {'_index': 'ai-alert-internet-2022-01',
     '_type': '_doc',
     '_id': 'QVLZTH4BW63vocbTuqY1',
     '_score': 1.0,
     '_source': {'category': 'Internet',
      'flow_id': 'B22010015',
      'event_type': 'alert',
      'in_iface': 'None',
      'alert_id': 'T0924',
      'alert_name': 'alert_name T0924',
      'src_ip': '192.168.70.76',
      'src_port': '7',
      'dst_ip': '8.8.8.4',
      'dst_port': '19',
      'risk_level': 'High',
      'protocol': '17',
      'start_time': '2022-01-06T18:13:13.517346+08:00',
      'end_time': '2022-01-06T18:13:13.517346+08:00',
      'timestamp': '2022-01-06T18:13:13.517346+08:00',
      'ingest_timestamp': '2022-01-06T18:13:13.517346+08:00',
      'module': 'byLongLife',
      'data_source': 'internet-flow*',
      'log_type': 'traffic',
      'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
       'value': ['7426', '8080', '17'],
       'description': ['90% of IAT<5000',
        'Commonly used port: 8080, 8070, 8060',
        'UDP']}}}]}}]

# %%
test_internet_list
# Out:
# [{'took': 1,
#   'timed_out': False,
#   '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#   'hits': {'total': {'value': 8, 'relation': 'eq'},
#    'max_score': 1.0,
#    'hits': [{'_index': 'ai-alert-internet-2021-12',
#      '_type': '_doc',
#      '_id': 'LlLYTH4BW63vocbT1aak',
#      '_score': 1.0,
#      '_source': {'category': 'Internet',
#       'flow_id': 'B21120001',
#       'event_type': 'alert',
#       'in_iface': 'None',
#       'alert_id': 'T0971',
#       'alert_name': 'alert_name T0971',
#       'src_ip': '192.168.70.78',
#       'src_port': '8',
#       'dst_ip': '8.8.8.9',
#       'dst_port': '77',
#       'risk_level': 'Low',
#       'protocol': '17',
#       'start_time': '2021-12-31T04:46:46.250193+08:00',
#       'end_time': '2021-12-31T04:46:46.250193+08:00',
#       'timestamp': '2021-12-31T04:46:46.250193+08:00',
#       'ingest_timestamp': '2021-12-31T04:46:46.250193+08:00',
#       'module': 'byLongLife',
# ...

# %%
internet_list[0]['hits']['hits']
# Out:
# [{'_index': 'ai-alert-internet-2021-12',
#   '_type': '_doc',
#   '_id': 'LlLYTH4BW63vocbT1aak',
#   '_score': 1.0,
#   '_source': {'category': 'Internet',
#    'flow_id': 'B21120001',
#    'event_type': 'alert',
#    'in_iface': 'None',
#    'alert_id': 'T0971',
#    'alert_name': 'alert_name T0971',
#    'src_ip': '192.168.70.78',
#    'src_port': '8',
#    'dst_ip': '8.8.8.9',
#    'dst_port': '77',
#    'risk_level': 'Low',
#    'protocol': '17',
#    'start_time': '2021-12-31T04:46:46.250193+08:00',
#    'end_time': '2021-12-31T04:46:46.250193+08:00',
#    'timestamp': '2021-12-31T04:46:46.250193+08:00',
#    'ingest_timestamp': '2021-12-31T04:46:46.250193+08:00',
#    'module': 'byLongLife',
#    'data_source': 'internet-flow*',
#    'log_type': 'traffic',
#    'explanation': {'name': ['Fwd IAT MEAN', 'Src Port', 'Potocol'],
#     'value': ['7426', '8080', '17'],
#     'description': ['90% of IAT<5000',
#      'Commonly used port: 8080, 8070, 8060',
#      'UDP']}}},
# ...

# %%
def get_explanation(in_list):
    explanation_list = []
    for index, value in enumerate(in_list): # iterate through an internet_list or intranat_list
        data_list = in_list[index]['hits']['hits'] # grab the data list we want, which is under the two hists
        for e_index, e_value in enumerate(data_list):
#             flow_id = data_list[e_index]['_source']['flow_id']
            flow_id = e_value['_source']['flow_id']
#             ex_data = data_list[e_index]['_source']['explanation']
            name = data_list[e_index]['_source']['explanation']['name']
            value = data_list[e_index]['_source']['explanation']['value']
            description = data_list[e_index]['_source']['explanation']['description']
            for i,j,k in zip(name,value,description):
                explanation_list.append((flow_id,{'name':i,'value':j,'description':k}))
#             explanation = (flow_id, explanation_list)
    return explanation_list

# %%
get_explanation(test_internet_list)
# Out:
# [('B21120001',
#   {'name': 'Fwd IAT MEAN', 'value': '7426', 'description': '90% of IAT<5000'}),
#  ('B21120001',
#   {'name': 'Src Port',
#    'value': '8080',
#    'description': 'Commonly used port: 8080, 8070, 8060'}),
#  ('B21120001', {'name': 'Potocol', 'value': '17', 'description': 'UDP'}),
#  ('B21120002',
#   {'name': 'Fwd IAT MEAN', 'value': '7426', 'description': '90% of IAT<5000'}),
#  ('B21120002',
#   {'name': 'Src Port',
#    'value': '8080',
#    'description': 'Commonly used port: 8080, 8070, 8060'}),
#  ('B21120002', {'name': 'Potocol', 'value': '17', 'description': 'UDP'}),
#  ('B21120003',
#   {'name': 'Fwd IAT MEAN', 'value': '7426', 'description': '90% of IAT<5000'}),
#  ('B21120003',
#   {'name': 'Src Port',
#    'value': '8080',
#    'description': 'Commonly used port: 8080, 8070, 8060'}),
#  ('B21120003', {'name': 'Potocol', 'value': '17', 'description': 'UDP'}),
#  ('B21120004',
# ...

# %%
a = ['a','b','c']
b = ['d','e','f']
c = ['g','h','i']
for i,j,k in zip(a,b,c):
    print(i,j,k)
# Out:
# a d g
# b e h
# c f i

# %%
def extract_data():
    es = connect_ES()
    index_list = [index for index in es.indices.get('*')]
    ex_index_list = [i for i in index_list if 'ai-alert-int' in i]
    internet_list = []
    intranet_list = []
    for i in ex_index_list:
        response = es.search(index=i)
        if i[9:17]=='internet':
            internet_list.append(response)
        elif i[9:17]=='intranet':
            intranet_list.append(response)
        else:
            print("error")
    internet = get_explanation(internet_list)
    intranet = get_explanation(intranet_list)
    final_data = {'internet':internet,'intranet':intranet}
    return final_data

# %%
def get_explanation_data_by_id(flow_id,options):
    all_data = extract_data()
    if options == 'internet':
        for data in all_data['internet']:
            if flow_id == data[0]:
                return data[1]
            else:
                print("The flow_id doesn't exist in internet list.")
    elif options == 'intranet':
        for data in all_data:
            if flow_id == data[0]:
                return data[1]
        else:
            print("The flow_id doesn't exist in intranet list.")
    else:
        print("There are some errors, please try again!")
#is it possible that internet and inranet list have same flow id?

# %%
test_data = get_explanation(test_internet_list)
df = pd.DataFrame(test_data)
# df.groupby()
df
# Out:
#             0                                                  1
# 0   B21120001  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 1   B21120001  {'name': 'Src Port', 'value': '8080', 'descrip...
# 2   B21120001  {'name': 'Potocol', 'value': '17', 'descriptio...
# 3   B21120002  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 4   B21120002  {'name': 'Src Port', 'value': '8080', 'descrip...
# 5   B21120002  {'name': 'Potocol', 'value': '17', 'descriptio...
# 6   B21120003  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 7   B21120003  {'name': 'Src Port', 'value': '8080', 'descrip...
# 8   B21120003  {'name': 'Potocol', 'value': '17', 'descriptio...
# 9   B21120004  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 10  B21120004  {'name': 'Src Port', 'value': '8080', 'descrip...
# 11  B21120004  {'name': 'Potocol', 'value': '17', 'descriptio...
# 12  B21120006  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# ...

# %%
df.columns=['id','data']
df.columns
# Out:
# Index(['id', 'data'], dtype='object')

# %%
df
# Out:
#            id                                               data
# 0   B21120001  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 1   B21120001  {'name': 'Src Port', 'value': '8080', 'descrip...
# 2   B21120001  {'name': 'Potocol', 'value': '17', 'descriptio...
# 3   B21120002  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 4   B21120002  {'name': 'Src Port', 'value': '8080', 'descrip...
# 5   B21120002  {'name': 'Potocol', 'value': '17', 'descriptio...
# 6   B21120003  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 7   B21120003  {'name': 'Src Port', 'value': '8080', 'descrip...
# 8   B21120003  {'name': 'Potocol', 'value': '17', 'descriptio...
# 9   B21120004  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 10  B21120004  {'name': 'Src Port', 'value': '8080', 'descrip...
# 11  B21120004  {'name': 'Potocol', 'value': '17', 'descriptio...
# 12  B21120006  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# ...

# %%
type(df)
df
# Out:
#            id                                               data
# 0   B21120001  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 1   B21120001  {'name': 'Src Port', 'value': '8080', 'descrip...
# 2   B21120001  {'name': 'Potocol', 'value': '17', 'descriptio...
# 3   B21120002  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 4   B21120002  {'name': 'Src Port', 'value': '8080', 'descrip...
# 5   B21120002  {'name': 'Potocol', 'value': '17', 'descriptio...
# 6   B21120003  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 7   B21120003  {'name': 'Src Port', 'value': '8080', 'descrip...
# 8   B21120003  {'name': 'Potocol', 'value': '17', 'descriptio...
# 9   B21120004  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# 10  B21120004  {'name': 'Src Port', 'value': '8080', 'descrip...
# 11  B21120004  {'name': 'Potocol', 'value': '17', 'descriptio...
# 12  B21120006  {'name': 'Fwd IAT MEAN', 'value': '7426', 'des...
# ...

# %%
df.groupby('id').groups
# Out:
# {'B21120001': [0, 1, 2], 'B21120002': [3, 4, 5], 'B21120003': [6, 7, 8], 'B21120004': [9, 10, 11], 'B21120006': [12, 13, 14], 'B21120007': [15, 16, 17], 'B21120008': [18, 19, 20], 'B21120009': [21, 22, 23], 'B2201000b': [24, 25, 26], 'B2201000c': [27, 28, 29], 'B2201000d': [30, 31, 32], 'B2201000f': [33, 34, 35], 'B22010010': [36, 37, 38], 'B22010011': [39, 40, 41], 'B22010012': [42, 43, 44], 'B22010013': [45, 46, 47], 'B22010014': [48, 49, 50], 'B22010015': [51, 52, 53]}

# %%
df1 = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df1
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df1.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0
